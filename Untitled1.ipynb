# %%
import json
with open('C:/Users/Shaun/.secret/yelp_api.json') as f: 
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# import the YelpAPI Class
from yelpapi import YelpAPI
# Create an instance with your key
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
# use our yelp_api variable's search_query method to perform our API call
search_results = yelp_api.search_query(location='NY, NY',
                                       term='Pizza')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 12400

# %%
import pandas as pd
biz = pd.DataFrame(search_results['businesses'])
biz.head(2)
# Out:
#                        id                           alias  \
# 0  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
# 1  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
#
#                   name                                          image_url  \
# 0            Juliana's  https://s3-media2.fl.yelpcdn.com/bphoto/od36nF...
# 1  Prince Street Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/PfI8oV...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2702
# 1      False  https://www.yelp.com/biz/prince-street-pizza-n...          5081
#
#                                           categories  rating  \
# 0             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 1  {'latitude': 40.72308755605564, 'longitude': -...  [delivery, pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 1     $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
#
#     display_phone     distance
# 0  (718) 596-6700   308.569844
# 1  (212) 966-4100  1961.877142

# %%
len(search_results['businesses'])
# Out:
# 20

# %%
# add offset to our original api call
search_results = yelp_api.search_query(location='NY, NY',
                                       term='Pizza',
                                       offset = 20)

# %%
biz20 = pd.DataFrame(search_results['businesses'])
biz20.head(2)
# Out:
#                        id                           alias  \
# 0  oJ_XSPZFpvIt6rvheSQl7A  bleecker-street-pizza-new-york
# 1  2xQmBB6w-W6lxiex80fA9A      luigis-pizzeria-brooklyn-4
#
#                     name                                          image_url  \
# 0  Bleecker Street Pizza  https://s3-media3.fl.yelpcdn.com/bphoto/OqM3pH...
# 1       Luigi's Pizzeria  https://s3-media4.fl.yelpcdn.com/bphoto/j8wXRU...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/bleecker-street-pizza...          2936
# 1      False  https://www.yelp.com/biz/luigis-pizzeria-brook...           288
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.7320627016512, 'longitude': -7...  [delivery, pickup]
# 1     {'latitude': 40.6897, 'longitude': -73.965369}          [delivery]
#
#   price                                           location         phone  \
# 0     $  {'address1': '69 7th Ave S', 'address2': None,...  +12129244466
# 1     $  {'address1': '326 Dekalb Ave', 'address2': '',...  +17187832430
#
#     display_phone     distance
# 0  (212) 924-4466  3073.574220
# 1  (718) 783-2430  3001.831815

# %%
## concatenate the previous results and new results. 
businesses = pd.concat([biz, biz20],
                      ignore_index=True)
display(businesses.head(3), businesses.tail(3))
# Out:
#                        id                           alias  \
# 0  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
# 1  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 2  WG639VkTjmK5dzydd1BBJA             rubirosa-new-york-2
#
#                   name                                          image_url  \
# 0            Juliana's  https://s3-media2.fl.yelpcdn.com/bphoto/od36nF...
# 1  Prince Street Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/PfI8oV...
# 2             Rubirosa  https://s3-media3.fl.yelpcdn.com/bphoto/l0Phrn...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2702
# 1      False  https://www.yelp.com/biz/prince-street-pizza-n...          5081
# 2      False  https://www.yelp.com/biz/rubirosa-new-york-2?a...          3193
#
#                                           categories  rating  \
# 0             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 2  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 1  {'latitude': 40.72308755605564, 'longitude': -...  [delivery, pickup]
# 2   {'latitude': 40.722766, 'longitude': -73.996233}            [pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 1     $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 2    $$  {'address1': '235 Mulberry St', 'address2': ''...  +12129650500
#
#     display_phone     distance
# 0  (718) 596-6700   308.569844
# 1  (212) 966-4100  1961.877142
# 2  (212) 965-0500  1932.946770
#                         id                        alias                 name  \
# 37  yH6t1JWcwkdWG4CS5KPvow  adriennes-pizzabar-new-york  Adrienne's Pizzabar
# 38  vVVmHacu2YAxKfpIjhfd1g             norma-new-york-5                Norma
# 39  C8j0q4Ma_S5hBGuAI-aaww       di-fara-pizza-brooklyn        Di Fara Pizza
#
#                                             image_url  is_closed  \
# 37  https://s3-media3.fl.yelpcdn.com/bphoto/YePG9J...      False
# 38  https://s3-media3.fl.yelpcdn.com/bphoto/qJKt5l...      False
# 39  https://s3-media1.fl.yelpcdn.com/bphoto/HWI1IP...      False
#
#                                                   url  review_count  \
# 37  https://www.yelp.com/biz/adriennes-pizzabar-ne...          1850
# 38  https://www.yelp.com/biz/norma-new-york-5?adju...           625
# 39  https://www.yelp.com/biz/di-fara-pizza-brookly...          3998
#
#                                            categories  rating  \
# 37  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 38  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 39             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                           coordinates        transactions  \
# 37  {'latitude': 40.70424819999999, 'longitude': -...  [delivery, pickup]
# 38   {'latitude': 40.743553, 'longitude': -73.980026}  [delivery, pickup]
# 39   {'latitude': 40.625093, 'longitude': -73.961531}                  []
#
#    price                                           location         phone  \
# 37    $$  {'address1': '54 Stone St', 'address2': None, ...  +12122483838
# 38    $$  {'address1': '438 3rd Ave', 'address2': None, ...  +12128890600
# 39    $$  {'address1': '1424 Ave J', 'address2': '', 'ad...  +17182581367
#
#      display_phone     distance
# 37  (212) 248-3838  1340.117592
# 38  (212) 889-0600  4409.483534
# 39  (718) 258-1367  9352.269073
